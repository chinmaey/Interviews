# %% [markdown]
# Write code for C++ porject for the vehicle tracking
# 5-10 min
# Then explain.

# %%
class client
{
	gps_reader gps;
	transmitter t;	
	receiver rx;
	receiver dis;
	
public:
	// singleton client
	Client(gps_reader g, ... ): gps(g), {}
	
	client_init()
	{
		thread gps;
		gps.init();
		...
	}
	
	client_run()
	{
		gps.start();
		...
	}
	
};

class gps_reader
{
	unit8t* buf;
	uint8t head;
	uint8t tail;
	public:
	static  unit16t MAX_BUFSIZE = 0xFFFF;
	
	// distructor
	~ gps_reader(){
	delete buf;
	bu=nullptr;
	}
	
	// constructor
	gps_reader()
	{
		buf = new unit8t[MAX_BUFSIZE];
		try:
		f=open_cread()
		
		except e;
			
		final:
			
		
		return;
	}
	
	gps_read()
	{
		tbuf=c_read();
		buf.append(tbuf,size);
	}
	
	init()
	
	start()
	
	calc
	
}


class transmitter{

};

class receiver{

}

class display{
};

# %% [markdown]
# Write a script to read the file
#
# How do you pass or fail the test

# %%
pass or fail

result =test(testid)

if("PASS" is in result):
	pass
else:
	fail 

cp fa fb

copy.py 


s = argc[1]
d = argc[2] 


with open(s) as f:
	f.seek(0)
	=
